# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import cmaes_experiment_execution
import helper
import skopt
from skopt.space import Real,Integer
import time

# %%
N = 100
iterations = 900
population_size = 200
max_2_sat_weights_seed = 0
max_2_sat_states_seed = 1
num_runs = 3

max_2_sat_weights = helper.init_weighted_max_sat_weights(N,max_2_sat_weights_seed)
max_2_sat_states = helper.init_weighted_max_sat_states(N,max_2_sat_states_seed)

# %% [markdown]
# CMA-ES
# Iterations = 1000
# Population Size = 200
# Sigma Energy
# 0.998 -677

# %%
x = max_2_sat_states
x0 = [[0.2],[1.0]]
y0 = None

dimensions = [
    Real(0.2,1.0,name='sigma'),
]

def objective_function(N,num_runs,seed_weights,x,sigma,iterations,population_size):
    print('Sigma:',sigma)
    final_energies = []
    for i in range(1,num_runs+1):
        print('Run',i)
        cmaes_model = cmaes_experiment_execution.CMAES(N,seed_weights)
        iteration_energies, times = cmaes_model.run(x,sigma,iterations,population_size)
        e = iteration_energies[-1]
        mean_e = np.mean(e,axis=None)
        final_energies.append(mean_e)
        print('Max & Min Final Run Energy',np.max(e),np.min(e))
        print('Mean',mean_e)
    print('Final Mean Run Energies',final_energies)
    y = np.mean(final_energies,axis=None)
    print('Final Mean Energy',y)
    return y

start_time = time.time()
optimise_result = skopt.gp_minimize(
    lambda p: objective_function(N,num_runs,max_2_sat_weights_seed,x,p[0],iterations,population_size),
    dimensions,
    n_calls=5,
    n_initial_points=3,
    x0=x0,
    y0=y0,
    random_state=None,
    verbose=True,
    n_jobs=-1,
)
run_time = time.time() - start_time
print(run_time / 60)
# Out:
# Iteration No: 1 started. Evaluating function at provided point.
# Sigma: 0.2
# Run 1
# (100_w,200)-aCMA-ES (mu_w=52.6,w_1=4%) in dimension 100 (seed=478376, Wed Jan  5 17:28:00 2022)
# Iteration 50
# Max,Min & Mean Energy -8.0 -148.0 -85.81
# Iteration 100
# Max,Min & Mean Energy -308.0 -568.0 -465.53
# Iteration 150
# Max,Min & Mean Energy -424.0 -604.0 -575.7
# Iteration 200
# Max,Min & Mean Energy -470.0 -616.0 -578.74
# Iteration 250
# Max,Min & Mean Energy -534.0 -626.0 -612.93
# Iteration 300
# Max,Min & Mean Energy -550.0 -626.0 -620.4
# Iteration 350
# Max,Min & Mean Energy -564.0 -626.0 -623.12
# Iteration 400
# Max,Min & Mean Energy -538.0 -626.0 -620.8
# Iteration 450
# Max,Min & Mean Energy -612.0 -626.0 -625.9
# Iteration 500
# Max,Min & Mean Energy -600.0 -626.0 -625.74
# Iteration 550
# Max,Min & Mean Energy -612.0 -626.0 -625.93
# Iteration 600
# Max,Min & Mean Energy -626.0 -626.0 -626.0
# Iteration 650
# Max,Min & Mean Energy -592.0 -626.0 -624.41
# Iteration 700
# Max,Min & Mean Energy -558.0 -626.0 -624.56
# Iteration 750
# Max,Min & Mean Energy -592.0 -626.0 -624.65
# Iteration 800
# Max,Min & Mean Energy -516.0 -626.0 -617.11
# Iteration 850
# Max,Min & Mean Energy -554.0 -626.0 -621.34
# Iteration 900
# Max,Min & Mean Energy -542.0 -626.0 -618.24
# {'maxiter': 900, 'tolfunhist': 1e-12, 'tolstagnation': 600}
# Max & Min Final Run Energy -544.0 -626.0
# Mean -618.16
# Run 2
# (100_w,200)-aCMA-ES (mu_w=52.6,w_1=4%) in dimension 100 (seed=523823, Wed Jan  5 17:30:03 2022)
# Iteration 50
# Max,Min & Mean Energy -74.0 -74.0 -74.0
# Iteration 100
# Max,Min & Mean Energy -74.0 -92.0 -74.09
# Iteration 150
# Max,Min & Mean Energy 156.0 -272.0 -40.4
# Iteration 200
# Max,Min & Mean Energy -212.0 -570.0 -398.79
# Iteration 250
# Max,Min & Mean Energy -406.0 -696.0 -626.67
# Iteration 300
# Max,Min & Mean Energy -480.0 -710.0 -670.93
# Iteration 350
# Max,Min & Mean Energy -506.0 -730.0 -666.78
# Iteration 400
# Max,Min & Mean Energy -670.0 -730.0 -726.48
# Iteration 450
# Max,Min & Mean Energy -680.0 -730.0 -724.42
# Iteration 500
# Max,Min & Mean Energy -658.0 -730.0 -726.57
# Iteration 550
# Max,Min & Mean Energy -668.0 -730.0 -721.49
# Iteration 600
# Max,Min & Mean Energy -688.0 -730.0 -728.21
# Iteration 650
# Max,Min & Mean Energy -730.0 -730.0 -730.0
# Iteration 700
# Max,Min & Mean Energy -680.0 -730.0 -729.56
# Iteration 750
# Max,Min & Mean Energy -692.0 -730.0 -729.36
# Iteration 800
# Max,Min & Mean Energy -680.0 -730.0 -727.46
# Iteration 850
# Max,Min & Mean Energy -688.0 -730.0 -729.57
# Iteration 900
# Max,Min & Mean Energy -730.0 -730.0 -730.0
# {'maxiter': 900, 'tolfunhist': 1e-12, 'tolstagnation': 600}
# Max & Min Final Run Energy -700.0 -730.0
# Mean -729.76
# Run 3
# (100_w,200)-aCMA-ES (mu_w=52.6,w_1=4%) in dimension 100 (seed=448419, Wed Jan  5 17:32:03 2022)
# Iteration 50
# Max,Min & Mean Energy -74.0 -74.0 -74.0
# Iteration 100
# Max,Min & Mean Energy -74.0 -74.0 -74.0
# Iteration 150
# Max,Min & Mean Energy -64.0 -74.0 -73.92
# Iteration 200
# Max,Min & Mean Energy 36.0 -372.0 -141.9
# Iteration 250
# Max,Min & Mean Energy -430.0 -596.0 -555.29
# Iteration 300
# Max,Min & Mean Energy -452.0 -602.0 -563.63
# Iteration 350
# Max,Min & Mean Energy -556.0 -602.0 -600.42
# Iteration 400
# Max,Min & Mean Energy -556.0 -602.0 -600.5
# Iteration 450
# Max,Min & Mean Energy -556.0 -602.0 -598.57
# Iteration 500
# Max,Min & Mean Energy -546.0 -602.0 -600.51
# Iteration 550
# Max,Min & Mean Energy -552.0 -602.0 -598.64
# Iteration 600
# Max,Min & Mean Energy -552.0 -602.0 -596.77
# Iteration 650
# Max,Min & Mean Energy -550.0 -602.0 -599.62
# Iteration 700
# Max,Min & Mean Energy -564.0 -602.0 -601.14
# Iteration 750
# Max,Min & Mean Energy -602.0 -602.0 -602.0
# Iteration 800
# Max,Min & Mean Energy -588.0 -602.0 -601.93
# Iteration 850
# Max,Min & Mean Energy -572.0 -602.0 -601.85
# Iteration 900
# Max,Min & Mean Energy -602.0 -602.0 -602.0
# {'maxiter': 900, 'tolfunhist': 1e-12, 'tolstagnation': 600}
# Max & Min Final Run Energy -584.0 -602.0
# Mean -601.91
# Final Mean Run Energies [-618.16, -729.76, -601.91]
# Final Mean Energy -649.9433333333333
# Sigma: 1.0
# Run 1
# (100_w,200)-aCMA-ES (mu_w=52.6,w_1=4%) in dimension 100 (seed=553097, Wed Jan  5 17:34:15 2022)
# Iteration 50
# Max,Min & Mean Energy 122.0 -290.0 -73.97
# Iteration 100
# Max,Min & Mean Energy -248.0 -574.0 -463.54
# Iteration 150
# Max,Min & Mean Energy -550.0 -636.0 -617.77
# Iteration 200
# Max,Min & Mean Energy -544.0 -648.0 -617.71
# Iteration 250
# Max,Min & Mean Energy -526.0 -652.0 -631.37
# Iteration 300
# Max,Min & Mean Energy -610.0 -652.0 -649.12
# Iteration 350
# Max,Min & Mean Energy -618.0 -652.0 -651.31
# Iteration 400
# Max,Min & Mean Energy -552.0 -652.0 -645.03
# Iteration 450
# Max,Min & Mean Energy -594.0 -652.0 -649.36
# Iteration 500
# Max,Min & Mean Energy -592.0 -652.0 -648.23
# Iteration 550
# Max,Min & Mean Energy -576.0 -652.0 -645.4
# Iteration 600
# Max,Min & Mean Energy -598.0 -652.0 -651.7
# Iteration 650
# Max,Min & Mean Energy -612.0 -652.0 -651.6
# Iteration 700
# Max,Min & Mean Energy -614.0 -652.0 -651.49
# Iteration 750
# Max,Min & Mean Energy -642.0 -652.0 -651.95
# Iteration 800
# Max,Min & Mean Energy -652.0 -652.0 -652.0
# Iteration 850
# Max,Min & Mean Energy -610.0 -652.0 -650.9
# Iteration 900
# Max,Min & Mean Energy -614.0 -652.0 -650.93
# {'maxiter': 900, 'tolfunhist': 1e-12, 'tolstagnation': 600}
# Max & Min Final Run Energy -614.0 -652.0
# Mean -651.62
# Run 2
# (100_w,200)-aCMA-ES (mu_w=52.6,w_1=4%) in dimension 100 (seed=463186, Wed Jan  5 17:36:27 2022)
# Iteration 50
# Max,Min & Mean Energy 154.0 -262.0 -7.16
# Iteration 100
# Max,Min & Mean Energy 156.0 -280.0 -39.45
# Iteration 150
# Max,Min & Mean Energy -238.0 -564.0 -441.47
# Iteration 200
# Max,Min & Mean Energy -484.0 -624.0 -585.3
# Iteration 250
# Max,Min & Mean Energy -460.0 -640.0 -587.79
# Iteration 300
# Max,Min & Mean Energy -578.0 -652.0 -644.06
# Iteration 350
# Max,Min & Mean Energy -578.0 -652.0 -648.19
# Iteration 400
# Max,Min & Mean Energy -556.0 -652.0 -639.1
# Iteration 450
# Max,Min & Mean Energy -602.0 -652.0 -649.2
# Iteration 500
# Max,Min & Mean Energy -594.0 -652.0 -647.05
# Iteration 550
# Max,Min & Mean Energy -578.0 -652.0 -647.61
# Iteration 600
# Max,Min & Mean Energy -586.0 -652.0 -647.35
# Iteration 650
# Max,Min & Mean Energy -596.0 -652.0 -648.56
# Iteration 700
# Max,Min & Mean Energy -576.0 -652.0 -647.75
# Iteration 750
# Max,Min & Mean Energy -594.0 -652.0 -648.12
# Iteration 800
# Max,Min & Mean Energy -546.0 -652.0 -637.23
# Iteration 850
# Max,Min & Mean Energy -586.0 -652.0 -649.77
# Iteration 900
# Max,Min & Mean Energy -586.0 -652.0 -649.71
# {'maxiter': 900, 'tolfunhist': 1e-12, 'tolstagnation': 600}
# Max & Min Final Run Energy -638.0 -652.0
# Mean -651.92
# Run 3
# (100_w,200)-aCMA-ES (mu_w=52.6,w_1=4%) in dimension 100 (seed=528084, Wed Jan  5 17:39:07 2022)
# Iteration 50
# Max,Min & Mean Energy -90.0 -470.0 -270.19
# Iteration 100
# Max,Min & Mean Energy -466.0 -646.0 -586.39
# Iteration 150
# Max,Min & Mean Energy -528.0 -664.0 -631.83
# Iteration 200
# Max,Min & Mean Energy -464.0 -674.0 -640.35
# Iteration 250
# Max,Min & Mean Energy -628.0 -674.0 -671.4
# Iteration 300
# Max,Min & Mean Energy -640.0 -674.0 -673.25
# Iteration 350
# Max,Min & Mean Energy -604.0 -674.0 -667.13
# Iteration 400
# Max,Min & Mean Energy -624.0 -674.0 -673.12
# Iteration 450
# Max,Min & Mean Energy -636.0 -674.0 -673.64
# Iteration 500
# Max,Min & Mean Energy -656.0 -674.0 -673.81
# Iteration 550
# Max,Min & Mean Energy -636.0 -674.0 -673.28
# Iteration 600
# Max,Min & Mean Energy -604.0 -674.0 -670.57
# Iteration 650
# Max,Min & Mean Energy -624.0 -674.0 -670.89
# Iteration 700
# Max,Min & Mean Energy -598.0 -674.0 -672.64
# Iteration 750
# Max,Min & Mean Energy -620.0 -674.0 -671.34
# Iteration 800
# Max,Min & Mean Energy -600.0 -674.0 -672.92
# Iteration 850
# Max,Min & Mean Energy -636.0 -674.0 -673.57
# Iteration 900
# Max,Min & Mean Energy -628.0 -674.0 -672.67
# {'maxiter': 900, 'tolfunhist': 1e-12, 'tolstagnation': 600}
# Max & Min Final Run Energy -628.0 -674.0
# Mean -672.72
# Final Mean Run Energies [-651.62, -651.92, -672.72]
# Final Mean Energy -658.7533333333333
# Iteration No: 1 ended. Evaluation done at provided point.
# Time taken: 846.5221
# Function value obtained: -658.7533
# Current minimum: -658.7533
# Iteration No: 2 started. Evaluating function at provided point.
# Sigma: 0.9323925734263339
# Run 1
# (100_w,200)-aCMA-ES (mu_w=52.6,w_1=4%) in dimension 100 (seed=470009, Wed Jan  5 17:42:06 2022)
# Iteration 50
# Max,Min & Mean Energy 16.0 -470.0 -223.77
# Iteration 100
# Max,Min & Mean Energy -442.0 -612.0 -560.93
# Iteration 150
# Max,Min & Mean Energy -484.0 -642.0 -598.41
# Iteration 200
# Max,Min & Mean Energy -592.0 -642.0 -640.18
# Iteration 250
# Max,Min & Mean Energy -616.0 -642.0 -641.55
# Iteration 300
# Max,Min & Mean Energy -620.0 -642.0 -641.57
# Iteration 350
# Max,Min & Mean Energy -608.0 -642.0 -641.27
# Iteration 400
# Max,Min & Mean Energy -642.0 -642.0 -642.0
# Iteration 450
# Max,Min & Mean Energy -608.0 -642.0 -641.4
# Iteration 500
# Max,Min & Mean Energy -624.0 -642.0 -641.64
# Iteration 550
# Max,Min & Mean Energy -642.0 -642.0 -642.0
# Iteration 600
# Max,Min & Mean Energy -608.0 -642.0 -640.84
# Iteration 650
# Max,Min & Mean Energy -612.0 -642.0 -641.3
# Iteration 700
# Max,Min & Mean Energy -620.0 -642.0 -641.8
# Iteration 750
# Max,Min & Mean Energy -570.0 -642.0 -639.47
# Iteration 800
# Max,Min & Mean Energy -616.0 -642.0 -641.87
# Iteration 850
# Max,Min & Mean Energy -632.0 -642.0 -641.87
# Iteration 900
# Max,Min & Mean Energy -620.0 -642.0 -641.86
# {'maxiter': 900, 'tolfunhist': 1e-12, 'tolstagnation': 600}
# Max & Min Final Run Energy -636.0 -642.0
# Mean -641.96
# Run 2
# (100_w,200)-aCMA-ES (mu_w=52.6,w_1=4%) in dimension 100 (seed=517984, Wed Jan  5 17:44:39 2022)
# Iteration 50
# Max,Min & Mean Energy -8.0 -392.0 -213.25
# Iteration 100
# Max,Min & Mean Energy -436.0 -594.0 -539.78
# Iteration 150
# Max,Min & Mean Energy -434.0 -638.0 -582.37
# Iteration 200
# Max,Min & Mean Energy -602.0 -638.0 -636.87
# Iteration 250
# Max,Min & Mean Energy -576.0 -638.0 -635.36
# Iteration 300
# Max,Min & Mean Energy -600.0 -638.0 -636.98
# Iteration 350
# Max,Min & Mean Energy -604.0 -638.0 -637.83
# Iteration 400
# Max,Min & Mean Energy -584.0 -638.0 -633.58
# Iteration 450
# Max,Min & Mean Energy -604.0 -638.0 -637.47
# Iteration 500
# Max,Min & Mean Energy -632.0 -638.0 -637.97
# Iteration 550
# Max,Min & Mean Energy -604.0 -638.0 -637.8
# Iteration 600
# Max,Min & Mean Energy -554.0 -638.0 -635.22
# Iteration 650
# Max,Min & Mean Energy -558.0 -638.0 -631.5
# Iteration 700
# Max,Min & Mean Energy -596.0 -638.0 -636.51
# Iteration 750
# Max,Min & Mean Energy -588.0 -638.0 -635.28
# Iteration 800
# Max,Min & Mean Energy -584.0 -638.0 -636.05
# Iteration 850
# Max,Min & Mean Energy -632.0 -638.0 -637.97
# Iteration 900
# Max,Min & Mean Energy -588.0 -638.0 -637.04
# {'maxiter': 900, 'tolfunhist': 1e-12, 'tolstagnation': 600}
# Max & Min Final Run Energy -588.0 -638.0
# Mean -636.92
# Run 3
# (100_w,200)-aCMA-ES (mu_w=52.6,w_1=4%) in dimension 100 (seed=467704, Wed Jan  5 17:47:10 2022)
# Iteration 50
# Max,Min & Mean Energy 184.0 -274.0 -53.8
# Iteration 100
# Max,Min & Mean Energy 34.0 -450.0 -202.23
# Iteration 150
# Max,Min & Mean Energy -470.0 -680.0 -606.98
# Iteration 200
# Max,Min & Mean Energy -552.0 -692.0 -667.54
# Iteration 250
# Max,Min & Mean Energy -666.0 -692.0 -691.77
# Iteration 300
# Max,Min & Mean Energy -634.0 -692.0 -689.8
# Iteration 350
# Max,Min & Mean Energy -650.0 -692.0 -690.81
# Iteration 400
# Max,Min & Mean Energy -608.0 -692.0 -687.5
# Iteration 450
# Max,Min & Mean Energy -616.0 -692.0 -687.97
# Iteration 500
# Max,Min & Mean Energy -654.0 -692.0 -691.68
# Iteration 550
# Max,Min & Mean Energy -634.0 -692.0 -688.93
# Iteration 600
# Max,Min & Mean Energy -692.0 -692.0 -692.0
# Iteration 650
# Max,Min & Mean Energy -692.0 -692.0 -692.0
# Iteration 700
# Max,Min & Mean Energy -692.0 -692.0 -692.0
# Iteration 750
# Max,Min & Mean Energy -692.0 -692.0 -692.0
# Iteration 800
# Max,Min & Mean Energy -654.0 -692.0 -691.37
# Iteration 850
# Max,Min & Mean Energy -650.0 -692.0 -691.11
# Iteration 900
# Max,Min & Mean Energy -654.0 -692.0 -691.72
# {'maxiter': 900, 'tolfunhist': 1e-12, 'tolstagnation': 600}
# Max & Min Final Run Energy -674.0 -692.0
# Mean -691.91
# Final Mean Run Energies [-641.96, -636.92, -691.91]
# Final Mean Energy -656.93
# Iteration No: 2 ended. Evaluation done at provided point.
# Time taken: 456.8903
# Function value obtained: -656.9300
# Current minimum: -658.7533
# Iteration No: 3 started. Evaluating function at random point.
# Sigma: 0.3106147207623301
# Run 1
# (100_w,200)-aCMA-ES (mu_w=52.6,w_1=4%) in dimension 100 (seed=481525, Wed Jan  5 17:49:43 2022)
# Iteration 50
# Max,Min & Mean Energy 94.0 -328.0 -102.73
# Iteration 100
# Max,Min & Mean Energy -416.0 -616.0 -565.67
# Iteration 150
# Max,Min & Mean Energy -544.0 -656.0 -627.8
# Iteration 200
# Max,Min & Mean Energy -562.0 -658.0 -649.18
# Iteration 250
# Max,Min & Mean Energy -598.0 -658.0 -650.97
# Iteration 300
# Max,Min & Mean Energy -592.0 -658.0 -653.72
# Iteration 350
# Max,Min & Mean Energy -620.0 -658.0 -657.19
# Iteration 400
# Max,Min & Mean Energy -598.0 -658.0 -651.99
# Iteration 450
# Max,Min & Mean Energy -612.0 -658.0 -657.49
# Iteration 500
# Max,Min & Mean Energy -612.0 -658.0 -657.31
# Iteration 550
# Max,Min & Mean Energy -612.0 -658.0 -656.13
# Iteration 600
# Max,Min & Mean Energy -606.0 -658.0 -655.84
# Iteration 650
# Max,Min & Mean Energy -584.0 -658.0 -656.19
# Iteration 700
# Max,Min & Mean Energy -624.0 -658.0 -656.9
# Iteration 750
# Max,Min & Mean Energy -658.0 -658.0 -658.0
# Iteration 800
# Max,Min & Mean Energy -640.0 -658.0 -657.82
# Iteration 850
# Max,Min & Mean Energy -616.0 -658.0 -657.79
# Iteration 900
# Max,Min & Mean Energy -658.0 -658.0 -658.0
# {'maxiter': 900, 'tolfun': 1e-11, 'tolfunhist': 1e-12, 'tolstagnation': 600}
# Max & Min Final Run Energy -658.0 -658.0
# Mean -658.0
# Run 2
# (100_w,200)-aCMA-ES (mu_w=52.6,w_1=4%) in dimension 100 (seed=526224, Wed Jan  5 17:52:23 2022)
# Iteration 50
# Max,Min & Mean Energy 130.0 -288.0 -108.82
# Iteration 100
# Max,Min & Mean Energy -392.0 -620.0 -541.25
# Iteration 150
# Max,Min & Mean Energy -474.0 -658.0 -612.19
# Iteration 200
# Max,Min & Mean Energy -616.0 -658.0 -657.63
# Iteration 250
# Max,Min & Mean Energy -628.0 -658.0 -656.92
# Iteration 300
# Max,Min & Mean Energy -612.0 -658.0 -657.16
# Iteration 350
# Max,Min & Mean Energy -602.0 -658.0 -654.75
# Iteration 400
# Max,Min & Mean Energy -624.0 -658.0 -657.65
# Iteration 450
# Max,Min & Mean Energy -578.0 -658.0 -656.45
# Iteration 500
# Max,Min & Mean Energy -616.0 -658.0 -657.16
# Iteration 550
# Max,Min & Mean Energy -620.0 -658.0 -656.42
# Iteration 600
# Max,Min & Mean Energy -604.0 -658.0 -656.66
# Iteration 650
# Max,Min & Mean Energy -624.0 -658.0 -657.57
# Iteration 700
# Max,Min & Mean Energy -658.0 -658.0 -658.0
# Iteration 750
# Max,Min & Mean Energy -632.0 -658.0 -657.63
# Iteration 800
# Max,Min & Mean Energy -632.0 -658.0 -657.35
# Iteration 850
# Max,Min & Mean Energy -620.0 -658.0 -657.68
# Iteration 900
# Max,Min & Mean Energy -636.0 -658.0 -657.89
# {'maxiter': 900, 'tolfunhist': 1e-12, 'tolstagnation': 600}
# Max & Min Final Run Energy -636.0 -658.0
# Mean -657.45
# Run 3
# (100_w,200)-aCMA-ES (mu_w=52.6,w_1=4%) in dimension 100 (seed=549721, Wed Jan  5 17:55:19 2022)
# Iteration 50
# Max,Min & Mean Energy 32.0 -416.0 -212.94
# Iteration 100
# Max,Min & Mean Energy -468.0 -600.0 -561.45
# Iteration 150
# Max,Min & Mean Energy -446.0 -620.0 -582.35
# Iteration 200
# Max,Min & Mean Energy -508.0 -634.0 -603.04
# Iteration 250
# Max,Min & Mean Energy -560.0 -634.0 -626.67
# Iteration 300
# Max,Min & Mean Energy -588.0 -634.0 -630.97
# Iteration 350
# Max,Min & Mean Energy -600.0 -634.0 -632.3
# Iteration 400
# Max,Min & Mean Energy -600.0 -634.0 -633.69
# Iteration 450
# Max,Min & Mean Energy -604.0 -634.0 -632.46
# Iteration 500
# Max,Min & Mean Energy -582.0 -634.0 -631.54
# Iteration 550
# Max,Min & Mean Energy -588.0 -634.0 -632.38
# Iteration 600
# Max,Min & Mean Energy -554.0 -634.0 -631.14
# Iteration 650
# Max,Min & Mean Energy -522.0 -634.0 -632.85
# Iteration 700
# Max,Min & Mean Energy -588.0 -634.0 -633.04
# Iteration 750
# Max,Min & Mean Energy -588.0 -634.0 -632.72
# Iteration 800
# Max,Min & Mean Energy -588.0 -634.0 -632.5
# Iteration 850
# Max,Min & Mean Energy -632.0 -634.0 -633.99
# Iteration 900
# Max,Min & Mean Energy -584.0 -634.0 -632.61
# {'maxiter': 900, 'tolfunhist': 1e-12, 'tolstagnation': 600}
# Max & Min Final Run Energy -584.0 -634.0
# Mean -631.09
# Final Mean Run Energies [-658.0, -657.45, -631.09]
# Final Mean Energy -648.8466666666667
# Iteration No: 3 ended. Evaluation done at random point.
# Time taken: 501.6176
# Function value obtained: -648.8467
# Current minimum: -658.7533
# Iteration No: 4 started. Evaluating function at random point.
# Sigma: 0.9058399345090866
# Run 1
# (100_w,200)-aCMA-ES (mu_w=52.6,w_1=4%) in dimension 100 (seed=520129, Wed Jan  5 17:58:05 2022)
# Iteration 50
# Max,Min & Mean Energy -118.0 -496.0 -329.45
# Iteration 100
# Max,Min & Mean Energy -442.0 -652.0 -578.28
# Iteration 150
# Max,Min & Mean Energy -524.0 -656.0 -629.7
# Iteration 200
# Max,Min & Mean Energy -594.0 -656.0 -653.73
# Iteration 250
# Max,Min & Mean Energy -610.0 -656.0 -653.49
# Iteration 300
# Max,Min & Mean Energy -614.0 -656.0 -655.68
# Iteration 350
# Max,Min & Mean Energy -564.0 -656.0 -652.94
# Iteration 400
# Max,Min & Mean Energy -610.0 -656.0 -654.33
# Iteration 450
# Max,Min & Mean Energy -596.0 -656.0 -653.46
# Iteration 500
# Max,Min & Mean Energy -600.0 -656.0 -651.91
# Iteration 550
# Max,Min & Mean Energy -610.0 -656.0 -655.15
# Iteration 600
# Max,Min & Mean Energy -650.0 -656.0 -655.97
# Iteration 650
# Max,Min & Mean Energy -592.0 -656.0 -654.7
# Iteration 700
# Max,Min & Mean Energy -610.0 -656.0 -654.34
# Iteration 750
# Max,Min & Mean Energy -610.0 -656.0 -655.6
# Iteration 800
# Max,Min & Mean Energy -610.0 -656.0 -654.76
# Iteration 850
# Max,Min & Mean Energy -606.0 -656.0 -653.8
# Iteration 900
# Max,Min & Mean Energy -618.0 -656.0 -655.32
# {'maxiter': 900, 'tolfunhist': 1e-12, 'tolstagnation': 600}
# Max & Min Final Run Energy -618.0 -656.0
# Mean -655.09
# Run 2
# (100_w,200)-aCMA-ES (mu_w=52.6,w_1=4%) in dimension 100 (seed=437733, Wed Jan  5 18:00:36 2022)
# Iteration 50
# Max,Min & Mean Energy 4.0 -378.0 -164.36
# Iteration 100
# Max,Min & Mean Energy -402.0 -582.0 -522.73
# Iteration 150
# Max,Min & Mean Energy -412.0 -610.0 -555.26
# Iteration 200
# Max,Min & Mean Energy -430.0 -640.0 -578.85
# Iteration 250
# Max,Min & Mean Energy -560.0 -658.0 -644.69
# Iteration 300
# Max,Min & Mean Energy -624.0 -658.0 -656.36
# Iteration 350
# Max,Min & Mean Energy -624.0 -658.0 -657.82
# Iteration 400
# Max,Min & Mean Energy -608.0 -658.0 -656.51
# Iteration 450
# Max,Min & Mean Energy -596.0 -658.0 -657.13
# Iteration 500
# Max,Min & Mean Energy -624.0 -658.0 -656.48
# Iteration 550
# Max,Min & Mean Energy -596.0 -658.0 -654.57
# Iteration 600
# Max,Min & Mean Energy -636.0 -658.0 -657.84
# Iteration 650
# Max,Min & Mean Energy -608.0 -658.0 -656.72
# Iteration 700
# Max,Min & Mean Energy -608.0 -658.0 -656.97
# Iteration 750
# Max,Min & Mean Energy -606.0 -658.0 -654.0
# Iteration 800
# Max,Min & Mean Energy -658.0 -658.0 -658.0
# Iteration 850
# Max,Min & Mean Energy -632.0 -658.0 -657.78
# Iteration 900
# Max,Min & Mean Energy -640.0 -658.0 -657.34
# {'maxiter': 900, 'tolfunhist': 1e-12, 'tolstagnation': 600}
# Max & Min Final Run Energy -632.0 -658.0
# Mean -657.29
# Run 3
# (100_w,200)-aCMA-ES (mu_w=52.6,w_1=4%) in dimension 100 (seed=515333, Wed Jan  5 18:03:00 2022)
# Iteration 50
# Max,Min & Mean Energy 52.0 -478.0 -169.39
# Iteration 100
# Max,Min & Mean Energy -420.0 -614.0 -561.86
# Iteration 150
# Max,Min & Mean Energy -452.0 -640.0 -581.14
# Iteration 200
# Max,Min & Mean Energy -566.0 -648.0 -639.85
# Iteration 250
# Max,Min & Mean Energy -550.0 -656.0 -640.45
# Iteration 300
# Max,Min & Mean Energy -634.0 -656.0 -655.79
# Iteration 350
# Max,Min & Mean Energy -600.0 -656.0 -651.69
# Iteration 400
# Max,Min & Mean Energy -602.0 -656.0 -654.55
# Iteration 450
# Max,Min & Mean Energy -626.0 -656.0 -655.35
# Iteration 500
# Max,Min & Mean Energy -656.0 -656.0 -656.0
# Iteration 550
# Max,Min & Mean Energy -634.0 -656.0 -655.73
# Iteration 600
# Max,Min & Mean Energy -656.0 -656.0 -656.0
# Iteration 650
# Max,Min & Mean Energy -656.0 -656.0 -656.0
# Iteration 700
# Max,Min & Mean Energy -656.0 -656.0 -656.0
# Iteration 750
# Max,Min & Mean Energy -656.0 -656.0 -656.0
# Iteration 800
# Max,Min & Mean Energy -630.0 -656.0 -655.87
# Iteration 850
# Max,Min & Mean Energy -656.0 -656.0 -656.0
# Iteration 900
# Max,Min & Mean Energy -626.0 -656.0 -655.6
# {'maxiter': 900, 'tolfunhist': 1e-12, 'tolstagnation': 600}
# Max & Min Final Run Energy -630.0 -656.0
# Mean -655.87
# Final Mean Run Energies [-655.09, -657.29, -655.87]
# Final Mean Energy -656.0833333333334
# Iteration No: 4 ended. Evaluation done at random point.
# Time taken: 450.7871
# Function value obtained: -656.0833
# Current minimum: -658.7533
# Iteration No: 5 started. Evaluating function at random point.
# 37.597253088156386

# %%
#filename = f'cmaes_p{population_size}_{run_time}_hyperparameters.gz'
#del objective_function
#print('Saving results to:',filename)
#skopt.dump(optimise_result,filename,store_objective=False)
# Out:
# Saving results to: cmaes_p200_4210.450691699982_hyperparameters.gz

# %%
sigma = optimise_result.x[0]
print('Sigma:',sigma)
print('Iterations:',iterations)
print('Population Size',population_size)
print('Energy',optimise_result.fun)
# Out:
# Sigma: 1.0
# Iterations: 900
# Population Size 200
# Energy -658.7533333333333
